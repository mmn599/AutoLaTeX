# %%
# %matplotlib inline
from skimage import io
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
from IPython.core import display as ICD

I = np.asarray(Image.open('InkSample.gif'))
plt.imshow(I, cmap="Greys_r")
# Out:
# (286, 409)
